# %%
from robspy.base import API

# %%
api = API()

# %%
len(api.get_events())
# Out:
# 1873

# %%
len(api.get_earthquakes())
# Out:
# 1873

# %%
mol = api.get_stations(place='MOL')

for s in mol:
    print('{:5} {} {} {}'.format(s.id_station, s.code, s.begin, s.end))
# Out:
#  1999 MOL1 2017-04-07 00:00:00 0000-00-00 00:00:00
#  2000 MOL2 2017-04-07 00:00:00 0000-00-00 00:00:00
#  2001 MOL3 2017-04-07 00:00:00 0000-00-00 00:00:00
#  2002 MOL4 2017-04-07 00:00:00 0000-00-00 00:00:00
#  2003 MOL5 2017-04-07 00:00:00 0000-00-00 00:00:00
#   181 MOLA 2004-08-18 00:00:00 0000-00-00 00:00:00
#   182 MOLB 2004-08-18 00:00:00 0000-00-00 00:00:00
#   545 MOLS 2008-06-03 00:00:00 0000-00-00 00:00:00
#  1543 MOLT 2008-06-03 00:00:00 0000-00-00 00:00:00

# %%
mol[-1].network
# Out:
# 'UCC'

# %%
events = api.get_measured_events(1543)
print(len(events))
print(events[0])
for e in events:
    print(e.id_earth, e.date, e.ML or e.MS or e.MW)
# Out:
# 136
# ...
# 3068 2008-07-12 2.2000000000
# 3070 2008-07-14 2.6000000000
# 3096 2008-08-09 2.2000000000
# 3098 2008-08-09 2.2000000000
# 3165 2008-09-12 2.2000000000
# 3167 2008-09-13 2.6000000000
# 3225 2008-12-20 2.4000000000
# 3232 2008-12-29 1.7000000000
# 3252 2009-02-21 2.0000000000
# 3273 2009-03-03 2.8000000000
# 3276 2009-03-05 1.7000000000
# 3288 2009-03-12 1.8000000000
# 3426 2009-07-12 1.8000000000
# 3492 2009-07-23 2.3000000000
# 3501 2009-08-05 2.7000000000
# 3552 2009-12-26 2.5000000000
# 3886 2010-06-07 2.1000000000
# 4523 2011-06-07 2.0000000000
# 4534 2011-06-22 3.0000000000
# 4557 2011-07-14 3.9000000000
# 4561 2011-07-22 2.4000000000
# 4566 2011-08-05 2.7000000000
# 4570 2011-08-14 2.9000000000
# 4571 2011-08-17 2.7000000000
# 4580 2011-09-08 4.3000000000
# 4602 2011-12-25 2.4000000000
# 4603 2011-12-27 2.5000000000
# 4632 2012-01-26 2.7000000000
# 4645 2012-02-16 2.8000000000
# 4656 2012-03-04 2.1000000000
# 4788 2012-10-18 3.2000000000
# 4794 2012-11-02 1.5000000000
# ...

# %%
from robspy.synthacc import API

# %%
api = API()

# %%
c = api.get_catalog()

# %%
len(c)
# Out:
# 1873

# %%
e = c[269]
