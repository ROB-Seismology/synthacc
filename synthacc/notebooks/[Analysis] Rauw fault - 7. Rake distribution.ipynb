# %%
from data import rauw_fault_surface_trace
from rupture import kinematic_rupture_calculator_logic_tree

# %%
## scenario
trace = rauw_fault_surface_trace(proj=3812) ## ETRS89 / Belgian Lambert 2008=)
print(trace.length)
fault_data = {'trace': trace, 'dip': 60}

magnitude = 6.5
rake = -80
# Out:
# 55180.99137310802

# %%
krclt = kinematic_rupture_calculator_logic_tree()
print(len(krclt))
# Out:
# 512

# %%
sub = {'rdc': 'RF'}
krc, leaf = krclt(sub)

# %%
r = krc(fault_data, magnitude, rake)

# %%
r.slip.plot()

# %%
r.rake.plot()

# %%
print(r.rake.min, r.rake.avg, r.rake.max)
print(((r.rake.values * r.slip.values)/r.slip.values.mean()).mean())
# Out:
# -123.32088274923476 -80.0 -40.55512981364192
# -80.30035422898592

# %% [markdown]
# use 15 as SD like GP (but no trunctation)
