# %%
import os

from synthacc.io.esgmd2 import read_cor
from synthacc.recordings import Recording

# %%
root_folder = %pwd

# %%
n = read_cor(os.path.join(root_folder, 'data', 'recordings', '004339xa.cor'))[1]
e = read_cor(os.path.join(root_folder, 'data', 'recordings', '004339ya.cor'))[1]
z = read_cor(os.path.join(root_folder, 'data', 'recordings', '004339za.cor'))[1]

r = Recording({'Z': z, 'E': e, 'N': n})

# %%
r.plot()
