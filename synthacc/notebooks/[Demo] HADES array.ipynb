# %%
from robspy.synthacc import API 
from synthacc.recordings import plot_seismograms

# %%
api = API()

# %%
r = api.get_recording('MOL1', '2018-06-19 08:00:00', '2018-06-19 08:00:30')
r.plot()
# Out:
# C:\Miniconda3\envs\phd_py36\lib\site-packages\obspy\signal\detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):

# %%
s = api.get_seismogram('MOL1', '2018-06-19 08:00:00', '2018-06-19 08:05:00', 'Z')
s.plot()
# Out:
# C:\Miniconda3\envs\phd_py36\lib\site-packages\obspy\signal\detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):

# %%
s1 = api.get_seismogram('MOL1', '2018-06-11 08:00:00', '2018-06-11 08:05:00', 'Z')
s2 = api.get_seismogram('MOL2', '2018-06-11 08:00:00', '2018-06-11 08:05:00', 'Z')
s3 = api.get_seismogram('MOL3', '2018-06-11 08:00:00', '2018-06-11 08:05:00', 'Z')
s4 = api.get_seismogram('MOL4', '2018-06-11 08:00:00', '2018-06-11 08:05:00', 'Z')
s5 = api.get_seismogram('MOL5', '2018-06-11 08:00:00', '2018-06-11 08:05:00', 'Z')
# Out:
# C:\Miniconda3\envs\phd_py36\lib\site-packages\obspy\signal\detrend.py:31: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if not np.issubdtype(data.dtype, float):

# %%
plot_seismograms([[s1], [s2], [s3], [s4], [s5]], titles=['1', '2', '3', '4', '5'])
